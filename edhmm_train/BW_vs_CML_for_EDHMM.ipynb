# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt 

from create_sequence_w_labels import *
from initial_guess import *
from cml_incomplete_edhmm import fit as cml_fit
from new_edhmm_bw import fit_edhmm as bw_fit

# %%
for i in range(10):
    T = 1024
    N = 64
    S = 2
    D = 2
    K = S*D
    L = 2
    noise = 0.3
    max_iter = 7

    A_gt, B_gt, pi_gt, P_gt, observations, states, labels = hmmgenerate(K, L, T, N, S, D, edhmm = True, complete = False)
    A_init, B_init, pi_init, P_init = get_initial_values_edhmm(A_gt, B_gt, P_gt, noise, D, have_P = True)

    A, B, P, pi, _, ln_P_cml = cml_fit(A_init, B_init, P_init, pi_init, S, D, observations, labels, max_iter)
    plt.show(plt.plot(ln_P_cml))
    
    A, B, pi, ln_P_bw, _, _ = bw_fit(A_init, B_init, pi_init, observations, D, NUM_ITER = 100)
    plt.show(plt.plot(ln_P_bw))
    
    print('The CML approach gives ' + str(np.exp((ln_P_cml[-1]) - (ln_P_bw[-1]))) + ' times better probability estimation than what BW approach does.')
# Out:
# The CML approach gives 1.001861645465483 times better probability estimation than what BW approach does.
# The CML approach gives 1.0017269623666432 times better probability estimation than what BW approach does.
# The CML approach gives 0.9990411942657955 times better probability estimation than what BW approach does.
# The CML approach gives 1.025717361742399 times better probability estimation than what BW approach does.
# The CML approach gives 0.9953479821110124 times better probability estimation than what BW approach does.
# The CML approach gives 1.000244718764313 times better probability estimation than what BW approach does.
# The CML approach gives 0.9999110286274397 times better probability estimation than what BW approach does.
# The CML approach gives 1.001612368102014 times better probability estimation than what BW approach does.
# The CML approach gives 0.9987136718672602 times better probability estimation than what BW approach does.
# The CML approach gives 1.0034805292878854 times better probability estimation than what BW approach does.
